# %% [markdown]
# <a href="https://colab.research.google.com/github/ansehoon1999/MG-DataAnaylsis/blob/main/%EC%84%B8%ED%9B%88/DataAnalysis_7_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

# %%
yester = datetime.today() - timedelta(1)

yseter =  '20200208'
print(yseter)
now_today = datetime.today().strftime("%Y%m%d")

my_api_key = 'encoder key'

# 서비스 url 주소
url = 'http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19InfStateJson'

# 서비스에 필요한 파라미터 모음
queryParams = '?' + \
'ServiceKey=' + '{}'.format(my_api_key) + \
'&pageNo='+ '1' + \
'&numOfRows='+ '999' + \
'&startCreateDt={}&endCreateDt={}'.format(yseter,now_today)

#서비스url에 필요한 파라미터들을 붙여서 응답결과를 얻음.
result = requests.get(url + queryParams)

# 응답결과 파싱하기. ( 사용자가 원하는 형태로 변경)
# 응답 key 값이 영문화 되어 식별이 어려워 openAPI 문서를 참고하여
# replayce 를 통해 결과를 한글화 했다.

result = result.content 
jsonString = json.dumps(xmltodict.parse(result), indent = 4)
jsonString = jsonString.replace('resultCode', '결과코드').replace('resultMsg', '결과메세지').replace('numOfRows', '한 페이지 결과 수').replace('pageNo', '페이지 수').replace('totalCount', '전체 결과 수').replace('seq', '게시글번호(감염현황 고유값)').replace('stateDt', '기준일').replace('stateTime', '기준시간').replace('decideCnt', '확진자 수').replace('clearCnt', '격리해제 수').replace('examCnt', '검사진행 수').replace('deathCnt', '사망자 수').replace('careCnt', '치료중 환자 수').replace('resutlNegCnt', '결과 음성 수').replace('accExamCnt', '누적 검사 수').replace('accExamCompCnt', '누적 검사 완료 수').replace('accDefRate', '누적 환진률').replace('createDt', '등록일시분초').replace('updateDt', '수정일시분초')

js = json.loads(jsonString)
# 파싱한 전체 결과 보기.
print(js)
# Out:
# 20200208
# {'response': {'header': {'결과코드': '00', '결과메세지': 'NORMAL SERVICE.'}, 'body': {'items': {'item': [{'누적 환진률': '1.6992241235', '누적 검사 수': '11472346', '누적 검사 완료 수': '11191343', '치료중 환자 수': '20724', '격리해제 수': '167365', '등록일시분초': '2021-07-26 09:40:26.165', '사망자 수': '2077', '확진자 수': '190166', '검사진행 수': '281003', '결과 음성 수': '11001177', '게시글번호(감염현황 고유값)': '584', '기준일': '20210726', '기준시간': '00:00', '수정일시분초': 'null'}, {'누적 환진률': '1.6924008113', '누적 검사 수': '11433347', '누적 검사 완료 수': '11158586', '치료중 환자 수': '20400', '격리해제 수': '166375', '등록일시분초': '2021-07-25 09:32:34.468', '사망자 수': '2073', '확진자 수': '188848', '검사진행 수': '274761', '결과 음성 수': '10969738', '게시글번호(감염현황 고유값)': '583', '기준일': '20210725', '기준시간': '00:00', '수정일시분초': 'null'}, {'누적 환진률': '1.6794988233', '누적 검사 수': '11430525', '누적 검사 완료 수': '11155828', '치료중 환자 수': '20048', '격리해제 수': '165246', '등록일시분초': '2021-07-24 09:38:51.376', '사망자 수': '2068', '확진자 수': '187362', '검사진행 수': '274697', '결과 음성 수': '10968466', '게시글번호(감염현황 고유값)': '582', '기준일': '20210724', '기준시간': '00:00', '수정일시분초': 'null'}, {'누적 환진률': '1.6717199382', '누적 검사 수': '11388305', '누적 검사 완료 수': '11110294', '치료중 환자 수': '19461', '격리해제 수': '164206', '등록일시분초': '2021-07-23 09:37:34.575', '사망자 수': '2066', '확진자 수': '185733', '검사진행 수': '278011', '결과 음성 수': '10924561', '게시글번호(감염현황 고유값)': '581', '기준일': '20210723', '기준시간': '00:00', '수정일시분초': 'null'}, {'누적 환진률': '1.6624163319', '누적 검사 수': '11343918', '누적 검사 완료 수': '11074422', '치료중 환자 수': '18967', '격리해제 수': '163073', '등록일시분초': '2021-07-22 09:39:47.617', '사망자 수': '2063', '확진자 수': '184103', '검사진행 수': '269496', '결과 음성 수': '10890319', '게시글번호(감염현황 고유값)': '580', '기준일': '20210722', '기준시간': '00:00', '수정일시분초': 'null'}, {'누적 환진률': '1.6499811252', '누적 검사 수': '11298677', '누적 검사 완료 수': '11046490', '치료중 환자 수': '18571', '격리해제 수': '161634', '등록일시분초': '2021-07-21 09:38:25.219', '사망자 수': '2060', '확진자 수': '182265', '검사진행 수': '252187', '결과 음성 수': '10864225', '게시글번호(감염현황 고유값)': '579', '기준일': '20210721', '기준시간': '00:00', '수정일시분초': 'null'}, {'누적 환진률': '1.6396458500', '누적 검사 수': '11251987', '누적 검사 완료 수': '11007316', '치료중 환자 수': '18075', '격리해제 수': '160347', '등록일시분초': '2021-07-20 09:37:01.254', '사망자 수': '2059', '확진자 수': '180481', '검사진행 수': '244671', '결과 음성 수': '10826835', '게시글번호(감염현황 고유값)': '578', '기준일': '20210720', '기준시간': '00:00', '수정일시분초': 'null'}, {'누적 환진률': '1.6348035828', '누적 검사 수': '11202434', '누적 검사 완료 수': '10961745', '치료중 환자 수': '17515', '격리해제 수': '159630', '등록일시분초': '2021-07-19 09:38:09.418', '사망자 수': '2058', '확진자 수': '179203', '검사진행 수': '240689', '결과 음성 수': '10782542', '게시글번호(감염현황 고유값)': '577', '기준일': '20210719', '기준시간': '00:00', '수정일시분초': 'null'}, {'누적 환진률': '1.6265280434', '누적 검사 수': '11175981', '누적 검사 완료 수': '10940543', '치료중 환자 수': '16941', '격리해제 수': '158953', '등록일시분초': '2021-07-18 09:33:01.419', '사망자 수': '2057', '확진자 수': '177951', '검사진행 수': '235438', '결과 음성 수': '10762592', '게시글번호(감염현황 고유값)': '576', '기준일': '20210718', '기준시간': '00:00', '수정일시분초': 'null'}, {'누적 환진률': '1.6160650601', '누적 검사 수': '11149226', '누적 검사 완료 수': '10921590', '치료중 환자 수': '16485', '격리해제 수': '157960', '등록일시분초': '2021-07-17 10:19:46.901', '사망자 수': '2055', '확진자 수': '176500', '검사진행 수': '227636', '결과 음성 수': '10745090', '게시글번호(감염현황 고유값)': '575', '기준일': '20210717', '기준시간': '00:00', '수정일시분초': 'null'}, {'누적 환진률': '1.6073434271', '누적 검사 수': '11108584', '누적 검사 완료 수': '10890392', '치료중 환자 수': '15882', '격리해제 수': '157113', '등록일시분초': '2021-07-16 09:41:57.584', '사망자 수': '2051', '확진자 수': '175046', '검사진행 수': '218192', '결과 음성 수': '10715346', '게시글번호(감염현황 고유값)': '574', '기준일': '20210716', '기준시간': '00:00', '수정일시분초': 'null'}, {'누적 환진률': '1.5982992594', '누적 검사 수': '11060456', '누적 검사 완료 수': '10855977', '치료중 환자 수': '14952', '격리해제 수': '156509', '등록일시분초': '2021-07-15 09:46:10.26', '사망자 수': '2050', '확진자 수': '173511', '검사진행 수': '204479', '결과 음성 수': '10682466', '게시글번호(감염현황 고유값)': '573', '기준일': '20210715', '기준시간': '00:00', '수정일시분초': 'null'}, {'누적 환진률': '1.5878057669', '누적 검사 수': '11008859', '누적 검사 완료 수': '10826954', '치료중 환자 수': '14372', '격리해제 수': '155491', '등록일시분초': '2021-07-1 ...

# %%
js_check_count = js["response"]['body']['items']['item'][0]['검사진행 수']
js = js["response"]['body']['items']['item']

pdata = pd.DataFrame(js)
pdata = pdata[['확진자 수']]
print(pdata)
# Out:
#       확진자 수
# 0    190166
# 1    188848
# 2    187362
# 3    185733
# 4    184103
# ..      ...
# 530      28
# 531      28
# 532      27
# 533      27
# 534      24
#
# [535 rows x 1 columns]

# %%
for i in range(len(pdata)) :
  pdata.iloc[i,0] = int(pdata.iloc[i,0])

num = []
for i in range(len(pdata)-1) :

  num.append(pdata.iloc[i,0] - pdata.iloc[i+1,0])

print(num)

# %% [markdown]
# #여가 만족 지수

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filename='/content/drive/MyDrive/happy_lesiure.csv'

# %%
import pandas as pd
import numpy as np

data = pd.read_csv(filename)
df = pd.DataFrame(data)
df = df[['구군', '평균']]
print('전국 시군구 여가 만족지수 데이터: ', len(df))
# Out:
# 전국 시군구 여가 만족지수 데이터:  229

# %%
df.head()
# Out:
#     구군      평균
# 0  종로구  0.6331
# 1   중구  0.6691
# 2  용산구  0.2817
# 3  성동구  0.3257
# 4  광진구  0.3313

# %%
raw_data = []

for i in range(len(df)) :
  tmp_list = [df.iloc[i,0], df.iloc[i,1]]
  raw_data.append(tmp_list)

print(raw_data)
# Out:
# [['종로구', 0.6331], ['중구', 0.6691], ['용산구', 0.2817], ['성동구', 0.3257], ['광진구', 0.3313], ['동대문구', 0.2329], ['중랑구', 0.1831], ['성북구', 0.267], ['강북구', 0.2337], ['도봉구', 0.3076], ['노원구', 0.1548], ['은평구', 0.2498], ['서대문구', 0.2175], ['마포구', 0.2337], ['양천구', 0.2737], ['강서구', 0.1998], ['구로구', 0.3594], ['금천구', 0.2391], ['영등포구', 0.371], ['동작구', 0.2002], ['관악구', 0.2037], ['서초구', 0.2724], ['강남구', 0.3043], ['송파구', 0.192], ['강동구', 0.2317], ['중구', 0.4288], ['서구', 0.1076], ['동구', 0.1358], ['영도구', 0.1243], ['부산진구', 0.1193], ['동래구', 0.0655], ['남구', 0.0871], ['북구', nan], ['해운대구', 0.1267], ['사하구', 0.0909], ['금정구', 0.0904], ['강서구', 0.2904], ['연제구', 0.0238], ['수영구', 0.0404], ['사상구', 0.0517], ['기장군', 0.5211], ['중구', 0.598], ['동구', 0.0965], ['서구', 0.1395], ['남구', 0.0817], ['북구', 0.2337], ['수성구', 0.2263], ['달서구', 0.2009], ['달성군', 0.3028], ['중구', 0.2992], ['동구', 0.3058], ['연수구', 0.1238], ['남동구', 0.0862], ['부평구', 0.0541], ['계양구', 0.1692], ['서구', 0.1622], ['미추홀구', 0.0991], ['강화군', 0.6199], ['옹진군', 0.5264], ['동구', 0.6748], ['서구', 0.3163], ['남구', 0.4459], ['북구', 0.47200000000000003], ['광산구', 0.3659], ['동구', 0.2359], ['중구', 0.3258], ['서구', 0.2666], ['유성구', 0.4697], ['대덕구', 0.4418], ['중구', 0.3197], ['남구', 0.3988], ['동구', 0.3528], ['북구', 0.4658], ['울주군', 0.555], ['세종시', 0.4478], ['수원시', 0.3505], ['성남시', 0.324], ['의정부시', 0.205], ['안양시', 0.3354], ['부천시', 0.1534], ['광명시', 0.2223], ['평택시', 0.2951], ['동두천시', 0.2116], ['안산시', 0.2747], ['고양시', 0.2897], ['과천시', 
# %%
data = pd.DataFrame(raw_data, columns = ['name', 'value'])
data
# Out:
#      name   value
# 0     종로구  0.6331
# 1      중구  0.6691
# 2     용산구  0.2817
# 3     성동구  0.3257
# 4     광진구  0.3313
# ..    ...     ...
# 224   함양군  0.6758
# 225   거창군  0.4838
# 226   합천군  0.7900
# 227   제주시  0.6948
# 228  서귀포시  0.6948
#
# [229 rows x 2 columns]

# %%
import folium
import pandas as pd

geo_json = "https://raw.githubusercontent.com/southkorea/southkorea-maps/master/kostat/2013/json/skorea_municipalities_geo_simple.json"


data = pd.DataFrame(raw_data, columns = ['name', 'value'])
data

m = folium.Map(
    location = [37.566345, 126.977893],
)

folium.Choropleth(
    geo_data = geo_json,
    name='choropleth',
    data = data,
    columns = ['name', 'value'],
    key_on = 'feature.properties.name',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_1755f840bcbe4f72b0a3c8f645bdd121%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1755f840bcbe4f72b0a3c8f645bdd121%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_1755f840bcbe4f72b0a3c8f645bdd121%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_1755f840bcbe4f72b0a3c8f645bdd121%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B37.566345%2C%20126.977893%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_8b65a9a6800e4e23975e9fbe337326d6%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D. ...

# %%
filename = "/content/drive/MyDrive/culture_center.csv"

import pandas as pd
import numpy as np

data = pd.read_csv(filename)
df = pd.DataFrame(data)
df = df[['fclt_name', 'x_cd', 'y_cd']]
print('문화원 데이터: ', len(df))
# Out:
# 문화원 데이터:  230

# %%
df.head()
# Out:
#   fclt_name       x_cd        y_cd
# 0     종로문화원  37.576098  126.980373
# 1     중구문화원  37.567521  126.986527
# 2     용산문화원  37.533425  126.951860
# 3     성동문화원  37.559311  127.036007
# 4     광진문화원  37.536513  127.096478

# %%
cent_dict = {}
cent_dict["store"] = df.iloc[1,0]

# %%
center = []

for i in range(len(df)) :
  cent_dict = {}
  cent_dict["store"] = df.iloc[i,0]
  cent_dict["loc"] = [df.iloc[i,1], df.iloc[i,2]]
  center.append(cent_dict)

print(center)
# Out:
# [{'store': '종로문화원', 'loc': [37.57609779999999, 126.98037269999999]}, {'store': '중구문화원', 'loc': [37.5675214, 126.9865268]}, {'store': '용산문화원', 'loc': [37.533425, 126.95186000000001]}, {'store': '성동문화원', 'loc': [37.5593111, 127.0360074]}, {'store': '광진문화원', 'loc': [37.5365126, 127.0964783]}, {'store': '동대문문화원', 'loc': [37.577820200000005, 127.0376308]}, {'store': '중랑문화원', 'loc': [37.573954, 127.0851055]}, {'store': '성북문화원', 'loc': [37.5897131, 127.00574979999999]}, {'store': '강북문화원', 'loc': [37.6409898, 127.0138781]}, {'store': '도봉문화원', 'loc': [37.6541028, 127.0386267]}, {'store': '노원문화원', 'loc': [37.628799, 127.0698009]}, {'store': '은평문화원', 'loc': [37.6036997, 126.92790169999999]}, {'store': '서대문문화원', 'loc': [37.5807597,
 'loc': [35.131965, 126.85981389999999]}, {'store': '남구문화원', 'loc': [35.122063700000005, 126.91740459999998]}, {'store': '북구문화원', 'loc': [35.1728543, 126.9136518]}, {'store': '광산문화원', 'loc': [35.14248370000001, 126.7951172]}, {'store': '동구문화원', 'loc': [36.3041702, 127.4593925]}, {'store': '중구문화원', 'loc': [36.3235403, 127.4243949]}, {'store': '서구문화원', 'loc': [36.344622799999996, 127.38556659999999]}, {'store': '유성문화원', 'loc': [36.3598555, 127.3408365]}, {'store': '대덕문화원', 'loc': [36.374115, 127.420651]}, {'store': '중구문화원', 'loc': [35.556 ...

# %%
from folium.plugins import MarkerCluster
marker_cluster = MarkerCluster().add_to(m)

for i in range(len(center)):
  folium.Marker(
    location=center[i]['loc'],
    popup=center[i]['store'],
    icon=folium.Icon(color='red',icon='ok'),
  ).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_1755f840bcbe4f72b0a3c8f645bdd121%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1755f840bcbe4f72b0a3c8f645bdd121%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_1755f840bcbe4f72b0a3c8f645bdd121%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_1755f840bcbe4f72b0a3c8f645bdd121%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B37.566345%2C%20126.977893%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBoun ...

# %% [markdown]
# # 0.2 이하인 곳만

# %%
filename='/content/drive/MyDrive/happy_lesiure.csv'

import pandas as pd
import numpy as np

data = pd.read_csv(filename)
df = pd.DataFrame(data)
df = df[['구군', '평균']]
print('전국 시군구 여가 만족지수 데이터: ', len(df))


raw_data = []

for i in range(len(df)) :
  if df.iloc[i,1] < 0.2 :
    tmp_list = [df.iloc[i,0], df.iloc[i,1]]
    raw_data.append(tmp_list)

print(raw_data)
# Out:
# 전국 시군구 여가 만족지수 데이터:  229
# [['중랑구', 0.1831], ['노원구', 0.1548], ['강서구', 0.1998], ['송파구', 0.192], ['서구', 0.1076], ['동구', 0.1358], ['영도구', 0.1243], ['부산진구', 0.1193], ['동래구', 0.0655], ['남구', 0.0871], ['해운대구', 0.1267], ['사하구', 0.0909], ['금정구', 0.0904], ['연제구', 0.0238], ['수영구', 0.0404], ['사상구', 0.0517], ['동구', 0.0965], ['서구', 0.1395], ['남구', 0.0817], ['연수구', 0.1238], ['남동구', 0.0862], ['부평구', 0.0541], ['계양구', 0.1692], ['서구', 0.1622], ['미추홀구', 0.0991], ['부천시', 0.1534], ['김해시', 0.1475], ['거제시', 0.1987], ['창원시', 0.12300000000000001]]

# %%
import folium
import pandas as pd

geo_json = "https://raw.githubusercontent.com/southkorea/southkorea-maps/master/kostat/2013/json/skorea_municipalities_geo_simple.json"


data = pd.DataFrame(raw_data, columns = ['name', 'value'])
data

m2 = folium.Map(
    location = [37.566345, 126.977893],
)

folium.Choropleth(
    geo_data = geo_json,
    name='choropleth',
    data = data,
    columns = ['name', 'value'],
    key_on = 'feature.properties.name',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
).add_to(m2)

m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_01416862c3854163b7893463299bd2a2%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_01416862c3854163b7893463299bd2a2%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_01416862c3854163b7893463299bd2a2%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_01416862c3854163b7893463299bd2a2%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B37.566345%2C%20126.977893%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_3a95b4ab87c148de92061e44f9665175%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D. ...

# %%
filename = "/content/drive/MyDrive/culture_center.csv"

import pandas as pd
import numpy as np

data = pd.read_csv(filename)
df = pd.DataFrame(data)
df = df[['fclt_name', 'x_cd', 'y_cd']]
print('문화원 데이터: ', len(df))
# Out:
# 문화원 데이터:  230

# %%
cent_dict = {}
cent_dict["store"] = df.iloc[1,0]

# %%
center = []

for i in range(len(df)) :
  cent_dict = {}
  cent_dict["store"] = df.iloc[i,0]
  cent_dict["loc"] = [df.iloc[i,1], df.iloc[i,2]]
  center.append(cent_dict)

print(center)
# Out:
# [{'store': '종로문화원', 'loc': [37.57609779999999, 126.98037269999999]}, {'store': '중구문화원', 'loc': [37.5675214, 126.9865268]}, {'store': '용산문화원', 'loc': [37.533425, 126.95186000000001]}, {'store': '성동문화원', 'loc': [37.5593111, 127.0360074]}, {'store': '광진문화원', 'loc': [37.5365126, 127.0964783]}, {'store': '동대문문화원', 'loc': [37.577820200000005, 127.0376308]}, {'store': '중랑문화원', 'loc': [37.573954, 127.0851055]}, {'store': '성북문화원', 'loc': [37.5897131, 127.00574979999999]}, {'store': '강북문화원', 'loc': [37.6409898, 127.0138781]}, {'store': '도봉문화원', 'loc': [37.6541028, 127.0386267]}, {'store': '노원문화원', 'loc': [37.628799, 127.0698009]}, {'store': '은평문화원', 'loc': [37.6036997, 126.92790169999999]}, {'store': '서대문문화원', 'loc': [37.5807597, 126.9315574]}, {'store': '마포문화원', 'loc': [37.5422304, 126.9554912]}, {'store': '양천문화원', 'loc': [37.516520899999996, 126.86334]}, {'store': '강서문화원', 'loc': [37.5446931, 126.843755]}, {'store': '구로문화원', 'loc': [37.4974422, 126.86304890000001]}, {'store': '금천문화원', 'loc': [37.4463967, 126.9044447]}, {'store': '영등포문화원', 'loc': [37.5161266, 126.91212639999999]}, {'store': '동작문화원', 'loc': [37.5044455, 126.94108840000001]}, {'store': '관악문화원', 'loc': [37.4675977, 126.9448709]}, {'store': '서초문화원', 'loc': [37.4818278, 127.0359572]}, {'store': '강남문화원', 'loc': [37.4964992, 127.03202879999999]}, {'store': '송파문화원', 'loc': [37.51068239999999, 127.07593680000001]}, {'store': '강동문화원', 'loc': [37.5457314, 127.14122250000001]}, {'store': '서구문화원', 'loc': [35.1019769, 129.0175964]}, {'store': '동구문화원', 'loc': [35.127117999999996, 129.0460588]}, {'store': '영도문화원', 'loc': [35.0752654, 129.06685900000002]}, {'store': '부산진문화원', 'loc': [35.1644972, 129.0517618]}, {'store': '동래문화원', 'loc': [35.2119507, 129.090546]}, {'store': '남구문화원', 'loc': [35.130495200000006, 129.1120832]}, {'store': '낙동문화원', 'loc': [35.2134392, 129.0057519]}, {'store': '해운대문화원', 'loc': [35.1820882, 129.12141409999998]}, {'store': '사하문화원', 'loc': [35.110033200000004, 128.9449571]}, {'store': '금정문화원', 'loc': [35.2472904, 129.0931868]}, {'store': '강서문화원', 'loc': [35.2125011, 128.9807034]}, {'store': '연제문화원', 'loc': [35.1842855, 129.071201]}, {'store': '수영문화원', 'loc': [35.15377279999999, 129.11852]}, {'store': '사상문화원', 'loc': [35.147376799999996, 128.9946897]}, {'store': '기장문화원', 'loc': [35.2352458, 129.221698]}, {'store': '중구문화원', 'loc': [35.8633973, 128.59656470000002]}, {'store': '동구팔공문화원', 'loc': [35.955940000000005, 128.68918190000002]}, {'store': '서구문화원', 'loc': [35.87279, 128.5455378]}, {'store': '남구문화원', 'loc': [35.8312933, 128.57697040000002]}, {'store': '북구문화원', 'loc': [35.9358673, 128.5451287]}, {'store': '수성문화원', 'loc': [35.8392041, 128.61815990000002]}, {'store': '달서구문화원', 'loc': [35.8434224, 128.5228263]}, {'store': '달성문화원', 'loc': [35.69888220000001, 128.4519775]}, {'store': '중구문화원', 'loc': [37.440175399999994, 126.629407]}, {'store': '화도진문화원', 'loc': [37.48228579999999, 126.6464107]}, {'store': '미추홀학산문화원', 'loc': [37.4495057, 126.66187839999999]}, {'store': '연수문화원', 'loc': [37.4263057, 126.6676686]}, {'store': '남동문화원', 'loc': [37.3874638, 126.7245963]}, {'store': '부평문화원', 'loc': [37.5121422, 126.7379081]}, {'store': '계양문화원', 'loc': [37.537440600000004, 126.7377601]}, {'store': '서구문화원', 'loc': [37.5156992, 126.67988989999999]}, {'store': '강화문화원', 'loc': [37.742549600000004, 126.48797250000001]}, {'store': '옹진문화원', 'loc': [37.4597859, 126.63185779999999]}, {'store': '동구문화원', 'loc': [35.1500907, 126.9181561]}, {'store': '서구문화원', 'loc': [35.131965, 126.85981389999999]}, {'store': '남구문화원', 'loc': [35.122063700000005, 126.91740459999998]}, {'store': '북구문화원', 'loc': [35.1728543, 126.9136518]}, {'store': '광산문화원', 'loc': [35.14248370000001, 126.7951172]}, {'store': '동구문화원', 'loc': [36.3041702, 127.4593925]}, {'store': '중구문화원', 'loc': [36.3235403, 127.4243949]}, {'store': '서구문화원', 'loc': [36.344622799999996, 127.38556659999999]}, {'store': '유성문화원', 'loc': [36.3598555, 127.3408365]}, {'store': '대덕문화원', 'loc': [36.374115, 127.420651]}, {'store': '중구문화원', 'loc': [35.556 ...

# %%
from folium.plugins import MarkerCluster
marker_cluster = MarkerCluster().add_to(m2)

for i in range(len(center)):
  folium.Marker(
    location=center[i]['loc'],
    popup=center[i]['store'],
    icon=folium.Icon(color='red',icon='ok'),
  ).add_to(marker_cluster)

m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_01416862c3854163b7893463299bd2a2%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_01416862c3854163b7893463299bd2a2%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_01416862c3854163b7893463299bd2a2%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_01416862c3854163b7893463299bd2a2%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B37.566345%2C%20126.977893%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBoun ...

# %% [markdown]
# 여가 만족 지수가 낮은 위치의 문화원
#
# 인천
# - 미추홀학산문화원
# - 화도진문화원
# - 연수문화원
# - 남동문화원
# - 부평문화원
# - 서구문화원
#
# 서울
# - 강서문화원
# - 송파문화원
# - 중랑문화원
# - 노원 문화원
#
# 대전
# - 서구문화원
# - 동구문화원
#
#
# 대구
# - 동구팔공문화원
# - 서구문화원
# - 남구문화원
#
# 울산
# - 동구문화원
# - 남구문화원
#
# 김해
# - 김해문화원
# - 강서문화원
#
#
# 부산
# - 사하문화원
# - 영도문화원
# - 사상문화원
# - 부산진문화원
# - 연제문화원
# - 수영문화원
# - 해운대문화원
# - 동래문화원
# - 금정문화원
# - 김해문화원
# - 노원문화원
#
# 거제
# - 거제문화원
#
# 광주
# - 동구문화원
# - 남구문화원
# - 서구문화원
